# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('factory_list.csv', encoding='cp949')
data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19048\1804250343.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('factory_list.csv', encoding='cp949')
#             시도명  시군구명          관리기관          회사명 공장구분 단지명 설립구분   입주형태 보유구분  \
# 0         서울특별시   종로구     서울특별시 종로구     남일문화 (주)   개별       일반   해당없음   임대
# 1         서울특별시   종로구     서울특별시 종로구    (주)에취.알.디   개별       일반   해당없음   임대
# 2         서울특별시   종로구     서울특별시 종로구  (주)코리아쉬핑가제트   개별       일반   해당없음   자가
# 3         서울특별시   종로구     서울특별시 종로구         삼영DP   개별       일반   해당없음   임대
# 4         서울특별시   종로구     서울특별시 종로구         삼진기획   개별       일반   해당없음   임대
# ...         ...   ...           ...          ...  ...  ..  ...    ...  ...
# 198233  제주특별자치도  서귀포시  제주특별자치도 서귀포시      (주)낙원산업   개별       일반   해당없음   자가
# 198234  제주특별자치도  서귀포시  제주특별자치도 서귀포시     (주)서일레미콘   개별       일반   해당없음   자가
# ...

# %%
data = data[['공장주소_지번', '생산품', '업종명', '용도지역']]

# %%
data.dropna()
# Out:
#                              공장주소_지번               생산품                   업종명  \
# 0               서울특별시 종로구 창성동 87-1번지               인쇄물           경 인쇄업 외 2 종
# 1              서울특별시 종로구 통의동 35-69번지  모형전시물,IC TESTER외            전시용 모형 제조업
# 2              서울특별시 종로구 통의동 35-6번지               주간신문       일반 서적 출판업 외 3 종
# 3              서울특별시 종로구 적선동 107-1번지                인쇄           경 인쇄업 외 2 종
# 4                  서울특별시 종로구 적선동 2번지    정부간행물(책자,광고기획)          기타 인쇄업 외 1 종
# ...                              ...               ...                   ...
# 198233  제주특별자치도 서귀포시 표선면 세화리 429-1번지               아스콘  아스팔트 콘크리트 및 혼합제품 제조업
# 198234     제주특별자치도 서귀포시 표선면 세화리 21번지               레미콘               레미콘 제조업
# 198235  제주특별자치도 서귀포시 표선면 세화리 231-2번지               산소수        기타 비알코올 음료 제조업
# 198236   제주특별자치도 서귀포시 표선면 세화리 1564번지                전분         전분제품 및 당류 제조업
# 198237    제주특별자치도 서귀포시 표선면 세화리 847번지               어성초  그 외 기타 식료품 제조업 외 1 종
#
#                             용도지역
# ...

# %%
cnt = 0
jeju_index = []
for tmp in data['공장주소_지번']:
    if '제주' in tmp:
        jeju_index.append(cnt)
    cnt += 1
jeju_index
# Out:
# [197545,
#  197546,
#  197547,
#  197548,
#  197549,
#  197550,
#  197551,
#  197552,
#  197553,
#  197554,
#  197555,
#  197556,
#  197557,
#  197558,
#  197559,
#  197560,
#  197561,
#  197562,
#  197563,
#  197564,
#  197565,
#  197566,
#  197567,
#  197568,
#  197569,
#  197570,
#  197571,
#  197572,
#  197573,
#  197574,
#  197575,
#  197576,
#  197577,
#  197578,
#  197579,
#  197580,
#  197581,
#  197582,
#  197583,
#  197584,
#  197585,
#  197586,
#  197587,
#  197588,
#  197589,
#  197590,
#  197591,
#  197592,
#  197593,
#  197594,
#  197595,
#  197596,
#  197597,
#  197598,
#  197599,
#  197600,
#  197601,
#  197602,
#  197603,
#  197604,
#  197605,
#  197606,
#  197607,
#  197608,
#  197609,
#  197610,
#  197611,
#  197612,
#  197613,
#  197614,
#  197615,
#  197616,
#  197617,
#  197618,
#  197619,
#  197620,
#  197621,
#  197622,
#  197623,
#  197624,
#  197625,
#  197626,
#  197627,
#  197628,
#  197629,
#  197630,
#  197631,
#  197632,
#  197633,
#  197634,
# ...

# %%
data.drop(jeju_index, inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19048\906676842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(jeju_index, inplace = True)

# %%
data.isnull().sum()
# Out:
# 공장주소_지번    0
# 생산품        1
# 업종명        0
# 용도지역       0
# dtype: int64

# %%
data[:197544]
# Out:
#                               공장주소_지번                생산품  \
# 0                서울특별시 종로구 창성동 87-1번지                인쇄물
# 1               서울특별시 종로구 통의동 35-69번지   모형전시물,IC TESTER외
# 2               서울특별시 종로구 통의동 35-6번지                주간신문
# 3               서울특별시 종로구 적선동 107-1번지                 인쇄
# 4                   서울특별시 종로구 적선동 2번지     정부간행물(책자,광고기획)
# ...                               ...                ...
# 197539  경상남도 합천군 대병면 유전리 961-3번지 외1필지  생활도자기,주방용 도자기 홈세트
# 197540       경상남도 합천군 대병면 장단리 649-1번지               장류제조
# 197541         경상남도 합천군 대병면 대지리 843번지                  쌀
# 197542       경상남도 합천군 용주면 장전리 627-2번지            화장품 제조업
# 197543      경상남도 합천군 용주면 방곡리 826-14번지  플라스틱관, 레미콘, 콘크리트관
#
#                                 업종명                      용도지역
# 0                       경 인쇄업 외 2 종  도시지역/주거지역/제2종일반주거지역/고도지구
# 1                        전시용 모형 제조업           도시지역/주거지역/주거지역/
# 2                   일반 서적 출판업 외 3 종           도시지역/주거지역/주거지역/
# ...

# %%
drop_index = data.loc[data['생산품'] == ' '].index

# %%
len(drop_index)
# Out:
# 97

# %%
data.drop(drop_index, inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19048\1659541718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(drop_index, inplace = True)

# %%
data
# Out:
#                           공장주소_지번                       생산품  \
# 0            서울특별시 종로구 창성동 87-1번지                       인쇄물
# 1           서울특별시 종로구 통의동 35-69번지          모형전시물,IC TESTER외
# 2           서울특별시 종로구 통의동 35-6번지                       주간신문
# 3           서울특별시 종로구 적선동 107-1번지                        인쇄
# 4               서울특별시 종로구 적선동 2번지            정부간행물(책자,광고기획)
# ...                           ...                       ...
# 197541     경상남도 합천군 대병면 대지리 843번지                         쌀
# 197542   경상남도 합천군 용주면 장전리 627-2번지                   화장품 제조업
# 197543  경상남도 합천군 용주면 방곡리 826-14번지         플라스틱관, 레미콘, 콘크리트관
# 197544      경상남도 합천군 용주면 봉기리 33번지                        톱밥
# 197746                             태양광 모듈 직류 컨트롤러/딥러닝 소프트웨어
#
#                                 업종명                      용도지역
# 0                       경 인쇄업 외 2 종  도시지역/주거지역/제2종일반주거지역/고도지구
# 1                        전시용 모형 제조업           도시지역/주거지역/주거지역/
# ...

# %%
drop_index = data[data['생산품'].isnull()].index

# %%
data.drop(drop_index, inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19048\1659541718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(drop_index, inplace = True)

# %%
data.isnull().sum()
# Out:
# 공장주소_지번    0
# 생산품        0
# 업종명        0
# 용도지역       0
# dtype: int64

# %%
drop_index = data[data['생산품'].isin(['23122','13222','33934','14199','14-2613','26329','6142'])].index

# %%
data.drop(drop_index, inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19048\1659541718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(drop_index, inplace = True)

# %%
data.to_csv('factory_list_final.csv', encoding='cp949', index = False)
